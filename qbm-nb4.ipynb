# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from qbm import QBM, Duality
from tqdm import tqdm

# matplotlib styling
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.size'] = '12'

# %%
s3 = QBM(28)
d3 = Duality(s3)
# Out:
# 100%|██████████| 28/28 [00:08<00:00,  3.28it/s]

# %%
d3.plot_harper_states(nc = 5, sh=True, cmap='hot')
# Out:
# 100%|██████████| 28/28 [00:11<00:00,  2.39it/s]

# %%
s4 = QBM(17)
d4 = Duality(s4)
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 20.68it/s]

# %%
d4.plot_harper_states(nc = 5, sh=False, cmap='hot')

# %%
(d4.s.H["H"] @ d4.shifted_harper_states["evecs"][16]) / d4.shifted_harper_states["evecs"][16]
# Out:
# matrix([[0.14105267+5.93519279e-02j],
#         [0.08363941+1.24124397e-01j],
#         [0.04294483+1.95967873e-01j],
#         [0.02446498+2.71965215e-01j],
#         [0.03069566+3.45923281e-01j],
#         [0.06079537+4.10010801e-01j],
#         [0.110699  +4.51484904e-01j],
#         [0.17366677+3.31960600e-01j],
#         [0.24119454-3.31960600e-01j],
#         [0.30416231-4.51484904e-01j],
#         [0.35406594-4.10010801e-01j],
#         [0.38416565-3.45923281e-01j],
#         [0.39039633-2.71965215e-01j],
#         [0.37191648-1.95967873e-01j],
#         [0.33122191-1.24124397e-01j],
#         [0.27380864-5.93519279e-02j],
#         [0.20743066+1.40867621e-15j]])

# %%
d4.shifted_harper_states["evecs"][16]

# %%
d4.plot_harper_states(nc = 5, sh=True, cmap='hot')
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 21.15it/s]
